# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # STATISTICHE DEI LAUREATI IN FISICA (TRIENNALE E MAGISTRALE) DAL 20.. AL 20..

# %% [markdown]
# Il notebooke è diviso in tre parti:
#
# - La prima parte comprende analisi statistiche dei voti di laurea e delle medie aritmetiche e ponderate dei laureati della laurea triennale in fisica;
# - La seconda parte comprende analisi statistiche dei voti di laurea e delle medie aritmetiche e ponderate dei laureati della laurea magistrale in fisica;
# - La terza parte comprende analisi statistiche dei voti di laurea e delle medie aritmetiche e ponderate dei laureati della laurea magistrale in astrofisica e astronomia.

# %% [markdown]
# ### STATISTICHE TRIENNALE

# %%
#TABELLA DEI DATI
df_t = pd.read_csv("Laureati_L_30_ridotto.csv")
display(df_t)
# Out:
#      ANNO_ACCA_LAUREA  CODICE_CORSO  \
# 0                2018         13647
# 1                2018         13647
# 2                2018         13647
# 3                2018         13646
# 4                2018         13646
# ..                ...           ...
# 965              2022         30046
# 966              2022         30046
# 967              2022         30046
# 968              2022         30046
# 969              2022         30046
#
#                               DESCRIZIONE_CORSO  \
# 0    FISICA E ASTROFISICA [L-270 - Ordin. 2009]
# 1    FISICA E ASTROFISICA [L-270 - Ordin. 2009]
# 2    FISICA E ASTROFISICA [L-270 - Ordin. 2009]
# 3                  FISICA [L-270 - Ordin. 2009]
# 4                  FISICA [L-270 - Ordin. 2009]
# ..                                          ...
# 965                FISICA [L-270 - Ordin. 2019]
# 966                FISICA [L-270 - Ordin. 2019]
# 967                FISICA [L-270 - Ordin. 2019]
# ...

# %%
#COLONNE DELLA TABELLA
columns = list(df_t.columns)
print("Le colonne della tabella sono: {}".format(columns))
# Out:
# Le colonne della tabella sono: ['ANNO_ACCA_LAUREA', 'CODICE_CORSO', 'DESCRIZIONE_CORSO', 'STRUTTURA_ORGANIZZATIVA', 'DIPARTIMENTO', 'TIPO_LAUREA', 'CLASSE', 'DURATA', 'TIPO_ISCRIZIONE', 'ANNO_ISCRIZIONE', 'PERCORSO_ECCELLENZA', 'DATA_PRENOTAZIONE', 'DATA_LAUREA', 'VOTO_TESI', 'DESC_TIPO_VOTO', 'MEDIA_PONDERATA', 'MEDIA_MATEMATICA', 'ETA_CONSEGUITA_LAUREA']

# %%
#STATISTICA DESCRITTIVA
df_t.describe()
# Out:
#        ANNO_ACCA_LAUREA  CODICE_CORSO  DURATA  ANNO_ISCRIZIONE   VOTO_TESI  \
# count        970.000000    970.000000   970.0       970.000000  970.000000
# mean        2019.873196  28138.984536     3.0         2.511340  103.519588
# std            1.297534   2465.054886     0.0         1.046087    7.885280
# min         2018.000000  13646.000000     3.0         1.000000   77.000000
# 25%         2019.000000  28204.000000     3.0         2.000000   98.000000
# 50%         2020.000000  28204.000000     3.0         3.000000  106.000000
# 75%         2021.000000  28204.000000     3.0         3.000000  111.000000
# max         2022.000000  30046.000000     3.0        10.000000  111.000000
#
#        MEDIA_PONDERATA  MEDIA_MATEMATICA  ETA_CONSEGUITA_LAUREA
# count       970.000000        970.000000             970.000000
# mean         26.207402         26.314113              22.765979
# std           2.270179          2.206697               2.318739
# ...

# %% [markdown]
# ### Istrogrammi

# %%
#ISTOGRAMMA VOTI DI LAUREA
#N_bins = 20
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO VOTI DI LAUREA TRIENNALE ")
plt.xlabel("Voto della tesi (in centodecimi)")
plt.ylabel("Occorrenze")
_, _, _ = plt.hist(df_t['VOTO_TESI'], color = 'darkred')

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO VOTI DI LAUREA TRIENNALE ")
plt.xlabel("Voto della tesi (in centodecimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_t['VOTO_TESI'], density = True, color = 'navy')

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_t['VOTO_TESI'], 90)
p20 = np.percentile(df_t['VOTO_TESI'], 80)
p30 = np.percentile(df_t['VOTO_TESI'], 70)
p40 = np.percentile(df_t['VOTO_TESI'], 60)
p50 = np.percentile(df_t['VOTO_TESI'], 50)


p10, p20, p30, p40, p50
# Out:
# (111.0, 111.0, 111.0, 110.0, 106.0)

# %% [markdown]
# I percentili relativi all'istogramma dei voti della tesi di laurea risultano poco indicativi (distribuzione molto piccata sul voto 110).

# %%
#ISTOGRAMMA MEDIA ARITMETICA
N_bins = 15
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO MEDIA ARIT. TRIENNALE ")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Occorrenze")
_, _, _ = plt.hist(df_t['MEDIA_MATEMATICA'], color = 'darkred', bins = N_bins)

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA ARIT. TRIENNALE ")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_t['MEDIA_MATEMATICA'], density = True, color = 'navy', bins = N_bins)

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_t['MEDIA_MATEMATICA'], 90)
p20 = np.percentile(df_t['MEDIA_MATEMATICA'], 80)
p30 = np.percentile(df_t['MEDIA_MATEMATICA'], 70)
p40 = np.percentile(df_t['MEDIA_MATEMATICA'], 60)
p50 = np.percentile(df_t['MEDIA_MATEMATICA'], 50)

print(f"Top 10 %: > {p10}")
print(f"Top 20 %: > {p20}")
print(f"Top 30 %: > {p30}")
print(f"Top 40 %: > {p40}")
print(f"Top 50 %: > {p50}")
# Out:
# Top 10 %: > 29.24
# Top 20 %: > 28.52
# Top 30 %: > 27.86
# Top 40 %: > 27.14
# Top 50 %: > 26.33

# %%
#ISTOGRAMMA MEDIA ARITMETICA
N_bins = 15
plt.figure(figsize=(15,8))
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA ARIT. TRIENNALE ")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Percentuale")
plt.vlines(p10, 0., 0.178, colors='lime', linestyles='solid', label = 'Top 10 %')
plt.vlines(p20, 0., 0.178, colors='red', linestyles='solid', label = 'Top 20 %')
plt.vlines(p30, 0., 0.178, colors='pink', linestyles='solid', label = 'Top 30 %')
plt.vlines(p40, 0., 0.178, colors='yellow', linestyles='solid', label = 'Top 40 %')
plt.vlines(p50, 0., 0.178, colors='brown', linestyles='solid', label = 'Top 50 %')
_, _, _ = plt.hist(df_t['MEDIA_MATEMATICA'], bins = N_bins, density = True, color = 'navy')
plt.legend(loc = 'upper left')

# %%
#ISTOGRAMMA MEDIA PONDERATA
N_bins = 15
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO MEDIA POND. TRIENNALE ")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Occorrenze")
_, _, _=plt.hist(df_t['MEDIA_PONDERATA'], color = 'darkred', bins = N_bins)

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA POND. TRIENNALE ")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_t['MEDIA_PONDERATA'], density = True, color = 'navy', bins = N_bins)

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_t['MEDIA_PONDERATA'], 90)
p20 = np.percentile(df_t['MEDIA_PONDERATA'], 80)
p30 = np.percentile(df_t['MEDIA_PONDERATA'], 70)
p40 = np.percentile(df_t['MEDIA_PONDERATA'], 60)
p50 = np.percentile(df_t['MEDIA_PONDERATA'], 50)

print(f"Top 10 %: > {p10}")
print(f"Top 20 %: > {p20}")
print(f"Top 30 %: > {p30}")
print(f"Top 40 %: > {p40}")
print(f"Top 50 %: > {p50}")
# Out:
# Top 10 %: > 29.232
# Top 20 %: > 28.490000000000002
# Top 30 %: > 27.769999999999996
# Top 40 %: > 27.09
# Top 50 %: > 26.200000000000003

# %%
#ISTOGRAMMA MEDIA ARITMETICA
N_bins = 15
plt.figure(figsize=(15,8))
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA POND. TRIENNALE ")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Percentuale")
plt.vlines(p10, 0., 0.178, colors='lime', linestyles='solid', label = 'Top 10 %')
plt.vlines(p20, 0., 0.178, colors='red', linestyles='solid', label = 'Top 20 %')
plt.vlines(p30, 0., 0.178, colors='pink', linestyles='solid', label = 'Top 30 %')
plt.vlines(p40, 0., 0.178, colors='yellow', linestyles='solid', label = 'Top 40 %')
plt.vlines(p50, 0., 0.178, colors='brown', linestyles='solid', label = 'Top 50 %')
_, _, _ = plt.hist(df_t['MEDIA_PONDERATA'], bins = N_bins, density = True, color = 'navy')
plt.legend(loc = 'upper left')

# %% [markdown]
# ### STATISTICHE MAGISTRALE FISICA

# %%
df_m_f = pd.read_csv("Laureati_LM_17-ridotto.csv")
display(df_m_f)
# Out:
#      ANNO_ACCA_LAUREA  CODICE_CORSO          DESCRIZIONE_CORSO  \
# 0                2018         15277  FISICA [LM - Ordin. 2011]
# 1                2018         16076  FISICA [LM - Ordin. 2012]
# 2                2018         16076  FISICA [LM - Ordin. 2012]
# 3                2018         16076  FISICA [LM - Ordin. 2012]
# 4                2018         16076  FISICA [LM - Ordin. 2012]
# ..                ...           ...                        ...
# 605              2022         30055  FISICA [LM - Ordin. 2019]
# 606              2022         30055  FISICA [LM - Ordin. 2019]
# 607              2022         30055  FISICA [LM - Ordin. 2019]
# 608              2022         30055  FISICA [LM - Ordin. 2019]
# 609              2022         30055  FISICA [LM - Ordin. 2019]
#
#                      STRUTTURA_ORGANIZZATIVA             DIPARTIMENTO  \
# 0    SCIENZE MATEMATICHE, FISICHE E NATURALI   Dipartimento di Fisica
# ...

# %%
#COLONNE DELLA TABELLA
columns = list(df_m_f.columns)
print("Le colonne della tabella sono: {}".format(columns))
# Out:
# Le colonne della tabella sono: ['ANNO_ACCA_LAUREA', 'CODICE_CORSO', 'DESCRIZIONE_CORSO', 'STRUTTURA_ORGANIZZATIVA', 'DIPARTIMENTO', 'TIPO_LAUREA', 'CLASSE', 'DURATA', 'TIPO_ISCRIZIONE', 'ANNO_ISCRIZIONE', 'PERCORSO_ECCELLENZA', 'DATA_PRENOTAZIONE', 'DATA_LAUREA', 'VOTO_TESI', 'DESC_TIPO_VOTO', 'MEDIA_PONDERATA', 'MEDIA_MATEMATICA', 'ETA_CONSEGUITA_LAUREA']

# %%
#STATISTICA DESCRITTIVA
df_m_f.describe()
# Out:
#        ANNO_ACCA_LAUREA  CODICE_CORSO  DURATA  ANNO_ISCRIZIONE   VOTO_TESI  \
# count        610.000000    610.000000   610.0       610.000000  610.000000
# mean        2019.816393  28672.000000     2.0         1.847541  109.837705
# std            1.256468   3028.030844     0.0         0.644315    2.163639
# min         2018.000000  15277.000000     2.0         1.000000   91.000000
# 25%         2019.000000  28216.000000     2.0         2.000000  110.000000
# 50%         2020.000000  29421.000000     2.0         2.000000  111.000000
# 75%         2021.000000  30055.000000     2.0         2.000000  111.000000
# max         2022.000000  30055.000000     2.0         6.000000  111.000000
#
#        MEDIA_PONDERATA  MEDIA_MATEMATICA  ETA_CONSEGUITA_LAUREA
# count       610.000000        610.000000             610.000000
# mean         29.122918         29.076443              25.240984
# std           0.852784          0.887098               2.261833
# ...

# %% [markdown]
# ### Istrogrammi

# %%
#ISTOGRAMMA VOTI DI LAUREA MAGISTRALE
#N_bins = 10
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO VOTI DI LAUREA MAGISTRALE (F)")
plt.xlabel("Voto della tesi (in centodecimi)")
plt.ylabel("Occorrenze")
_, _, _ = plt.hist(df_m_f['VOTO_TESI'], color = 'darkred')

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO VOTI DI LAUREA MAGISTRALE (F) ")
plt.xlabel("Voto della tesi (in centodecimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_m_f['VOTO_TESI'], density = True, color = 'navy')

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_m_f['VOTO_TESI'], 90)
p20 = np.percentile(df_m_f['VOTO_TESI'], 80)
p30 = np.percentile(df_m_f['VOTO_TESI'], 70)
p40 = np.percentile(df_m_f['VOTO_TESI'], 60)
p50 = np.percentile(df_m_f['VOTO_TESI'], 50)


p10, p20, p30, p40, p50
# Out:
# (111.0, 111.0, 111.0, 111.0, 111.0)

# %% [markdown]
# I percentili relativi all'istogramma dei voti della tesi di laurea risultano poco indicativi (distribuzione molto piccata sul voto 110).

# %%
#ISTOGRAMMA MEDIA ARITMETICA
N_bins = 15
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO MEDIA ARIT. MAGISTRALE (F)")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Occorrenze")
_, _, _ = plt.hist(df_m_f['MEDIA_MATEMATICA'], color = 'darkred', bins = N_bins)

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA ARIT. MAGISTRALE (F) ")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_m_f['MEDIA_MATEMATICA'], density = True, color = 'navy', bins = N_bins)

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_m_f['MEDIA_MATEMATICA'], 90)
p20 = np.percentile(df_m_f['MEDIA_MATEMATICA'], 80)
p30 = np.percentile(df_m_f['MEDIA_MATEMATICA'], 70)
p40 = np.percentile(df_m_f['MEDIA_MATEMATICA'], 60)
p50 = np.percentile(df_m_f['MEDIA_MATEMATICA'], 50)

print(f"Top 10 %: > {p10}")
print(f"Top 20 %: > {p20}")
print(f"Top 30 %: > {p30}")
print(f"Top 40 %: > {p40}")
print(f"Top 50 %: > {p50}")
# Out:
# Top 10 %: > 29.92
# Top 20 %: > 29.83
# Top 30 %: > 29.67
# Top 40 %: > 29.5
# Top 50 %: > 29.27

# %%
#ISTOGRAMMA MEDIA ARITMETICA
N_bins = 15
plt.figure(figsize=(15,8))
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA ARIT. MAGISTRALE (F) ")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Percentuale")
plt.vlines(p10, 0., 0.9, colors='lime', linestyles='solid', label = 'Top 10 %')
plt.vlines(p20, 0., 0.9, colors='red', linestyles='solid', label = 'Top 20 %')
plt.vlines(p30, 0., 0.9, colors='pink', linestyles='solid', label = 'Top 30 %')
plt.vlines(p40, 0., 0.9, colors='yellow', linestyles='solid', label = 'Top 40 %')
plt.vlines(p50, 0., 0.9, colors='brown', linestyles='solid', label = 'Top 50 %')
_, _, _ = plt.hist(df_m_f['MEDIA_MATEMATICA'], bins = N_bins, density = True, color = 'navy')
plt.legend(loc = 'upper left')

# %%
#ISTOGRAMMA MEDIA PONDERATA
N_bins = 15
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO MEDIA POND. MAGISTRALE ")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Occorrenze")
_, _, _=plt.hist(df_m_f['MEDIA_PONDERATA'], color = 'darkred', bins = N_bins)

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA POND. MAGISTRALE ")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_m_f['MEDIA_PONDERATA'], density = True, color = 'navy', bins = N_bins)

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_m_f['MEDIA_PONDERATA'], 90)
p20 = np.percentile(df_m_f['MEDIA_PONDERATA'], 80)
p30 = np.percentile(df_m_f['MEDIA_PONDERATA'], 70)
p40 = np.percentile(df_m_f['MEDIA_PONDERATA'], 60)
p50 = np.percentile(df_m_f['MEDIA_PONDERATA'], 50)

print(f"Top 10 %: > {p10}")
print(f"Top 20 %: > {p20}")
print(f"Top 30 %: > {p30}")
print(f"Top 40 %: > {p40}")
print(f"Top 50 %: > {p50}")
# Out:
# Top 10 %: > 29.92
# Top 20 %: > 29.84
# Top 30 %: > 29.68
# Top 40 %: > 29.54
# Top 50 %: > 29.33

# %%
#ISTOGRAMMA MEDIA PONDERATA
N_bins = 15
plt.figure(figsize=(15,8))
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA POND. MAGISTRALE ")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Percentuale")
plt.vlines(p10, 0., 0.9, colors='lime', linestyles='solid', label = 'Top 10 %')
plt.vlines(p20, 0., 0.9, colors='red', linestyles='solid', label = 'Top 20 %')
plt.vlines(p30, 0., 0.9, colors='pink', linestyles='solid', label = 'Top 30 %')
plt.vlines(p40, 0., 0.9, colors='yellow', linestyles='solid', label = 'Top 40 %')
plt.vlines(p50, 0., 0.9, colors='brown', linestyles='solid', label = 'Top 50 %')
_, _, _ = plt.hist(df_m_f['MEDIA_PONDERATA'], bins = N_bins, density = True, color = 'navy')
plt.legend(loc = 'upper left')

# %% [markdown]
# ### STATISTICHE MAGISTRALE ASTROFISICA E ASTRONOMIA

# %%
df_m_a = pd.read_csv("Laureati_LM_58-ridotto.csv")
display(df_m_a)
# Out:
#      ANNO_ACCA_LAUREA  CODICE_CORSO  \
# 0                2018         15278
# 1                2018         15278
# 2                2018         15278
# 3                2018         15278
# 4                2018         15278
# ..                ...           ...
# 97               2022         30060
# 98               2022         30060
# 99               2022         30060
# 100              2022         30060
# 101              2022         30060
#
#                                DESCRIZIONE_CORSO  \
# 0    ASTRONOMIA E ASTROFISICA [LM - Ordin. 2011]
# 1    ASTRONOMIA E ASTROFISICA [LM - Ordin. 2011]
# 2    ASTRONOMIA E ASTROFISICA [LM - Ordin. 2011]
# 3    ASTRONOMIA E ASTROFISICA [LM - Ordin. 2011]
# 4    ASTRONOMIA E ASTROFISICA [LM - Ordin. 2011]
# ..                                           ...
# 97   ASTRONOMIA E ASTROFISICA [LM - Ordin. 2019]
# 98   ASTRONOMIA E ASTROFISICA [LM - Ordin. 2019]
# 99   ASTRONOMIA E ASTROFISICA [LM - Ordin. 2019]
# ...

# %%
#COLONNE DELLA TABELLA
columns = list(df_m_a.columns)
print("Le colonne della tabella sono: {}".format(columns))
# Out:
# Le colonne della tabella sono: ['ANNO_ACCA_LAUREA', 'CODICE_CORSO', 'DESCRIZIONE_CORSO', 'STRUTTURA_ORGANIZZATIVA', 'DIPARTIMENTO', 'TIPO_LAUREA', 'CLASSE', 'DURATA', 'TIPO_ISCRIZIONE', 'ANNO_ISCRIZIONE', 'PERCORSO_ECCELLENZA', 'DATA_PRENOTAZIONE', 'DATA_LAUREA', 'VOTO_TESI', 'DESC_TIPO_VOTO', 'MEDIA_PONDERATA', 'MEDIA_MATEMATICA', 'ETA_CONSEGUITA_LAUREA']

# %%
#STATISTICA DESCRITTIVA
df_m_a.describe()
# Out:
#        ANNO_ACCA_LAUREA  CODICE_CORSO  DURATA  ANNO_ISCRIZIONE   VOTO_TESI  \
# count        102.000000    102.000000   102.0       102.000000  102.000000
# mean        2019.774510  21792.490196     2.0         1.911765  110.039216
# std            1.319367   7382.485366     0.0         0.945054    1.616264
# min         2018.000000  14566.000000     2.0         1.000000  104.000000
# 25%         2019.000000  15278.000000     2.0         1.250000  110.000000
# 50%         2020.000000  15278.000000     2.0         2.000000  111.000000
# 75%         2021.000000  30060.000000     2.0         2.000000  111.000000
# max         2022.000000  30060.000000     2.0         8.000000  111.000000
#
#        MEDIA_PONDERATA  MEDIA_MATEMATICA  ETA_CONSEGUITA_LAUREA
# count       102.000000        102.000000             102.000000
# mean         29.165000         29.109804              25.539216
# std           0.810797          0.862410               2.319404
# ...

# %% [markdown]
# ### Istrogrammi

# %%
#ISTOGRAMMA VOTI DI LAUREA MAGISTRALE
#N_bins = 10
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO VOTI DI LAUREA MAGISTRALE (A)")
plt.xlabel("Voto della tesi (in centodecimi)")
plt.ylabel("Occorrenze")
_, _, _ = plt.hist(df_m_a['VOTO_TESI'], color = 'darkred')

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO VOTI DI LAUREA MAGISTRALE (A) ")
plt.xlabel("Voto della tesi (in centodecimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_m_a['VOTO_TESI'], density = True, color = 'navy')

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_m_a['VOTO_TESI'], 90)
p20 = np.percentile(df_m_a['VOTO_TESI'], 80)
p30 = np.percentile(df_m_a['VOTO_TESI'], 70)
p40 = np.percentile(df_m_a['VOTO_TESI'], 60)
p50 = np.percentile(df_m_a['VOTO_TESI'], 50)


p10, p20, p30, p40, p50
# Out:
# (111.0, 111.0, 111.0, 111.0, 111.0)

# %% [markdown]
# I percentili relativi all'istogramma dei voti della tesi di laurea risultano poco indicativi (distribuzione molto piccata sul voto 110).

# %%
#ISTOGRAMMA MEDIA ARITMETICA
N_bins = 15
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO MEDIA ARIT. MAGISTRALE (A)")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Occorrenze")
_, _, _ = plt.hist(df_m_a['MEDIA_MATEMATICA'], color = 'darkred', bins = N_bins)

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA ARIT. MAGISTRALE (A) ")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_m_a['MEDIA_MATEMATICA'], density = True, color = 'navy', bins = N_bins)

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_m_a['MEDIA_MATEMATICA'], 90)
p20 = np.percentile(df_m_a['MEDIA_MATEMATICA'], 80)
p30 = np.percentile(df_m_a['MEDIA_MATEMATICA'], 70)
p40 = np.percentile(df_m_a['MEDIA_MATEMATICA'], 60)
p50 = np.percentile(df_m_a['MEDIA_MATEMATICA'], 50)

print(f"Top 10 %: > {p10}")
print(f"Top 20 %: > {p20}")
print(f"Top 30 %: > {p30}")
print(f"Top 40 %: > {p40}")
print(f"Top 50 %: > {p50}")
# Out:
# Top 10 %: > 30.0
# Top 20 %: > 29.92
# Top 30 %: > 29.75
# Top 40 %: > 29.5
# Top 50 %: > 29.25

# %%
#ISTOGRAMMA MEDIA ARITMETICA
N_bins = 15
plt.figure(figsize=(15,8))
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA ARIT. MAGISTRALE (A) ")
plt.xlabel("Media aritmetica (in 30 esimi)")
plt.ylabel("Percentuale")
plt.vlines(p10, 0., 0.9, colors='lime', linestyles='solid', label = 'Top 10 %')
plt.vlines(p20, 0., 0.9, colors='red', linestyles='solid', label = 'Top 20 %')
plt.vlines(p30, 0., 0.9, colors='pink', linestyles='solid', label = 'Top 30 %')
plt.vlines(p40, 0., 0.9, colors='yellow', linestyles='solid', label = 'Top 40 %')
plt.vlines(p50, 0., 0.9, colors='brown', linestyles='solid', label = 'Top 50 %')
_, _, _ = plt.hist(df_m_a['MEDIA_MATEMATICA'], bins = N_bins, density = True, color = 'navy')
plt.legend(loc = 'upper left')

# %%
#ISTOGRAMMA MEDIA PONDERATA
N_bins = 15
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.title("ISTOGRAMMA NON NORMALIZZATO MEDIA POND. MAGISTRALE (A)")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Occorrenze")
_, _, _=plt.hist(df_m_a['MEDIA_PONDERATA'], color = 'darkred', bins = N_bins)

plt.subplot(1, 2, 2)
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA POND. MAGISTRALE (A)")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Percentuale")
_, _, _ = plt.hist(df_m_a['MEDIA_PONDERATA'], density = True, color = 'navy', bins = N_bins)

# %%
#PERCENTILI VOTO DI LAUREA
p10 = np.percentile(df_m_a['MEDIA_PONDERATA'], 90)
p20 = np.percentile(df_m_a['MEDIA_PONDERATA'], 80)
p30 = np.percentile(df_m_a['MEDIA_PONDERATA'], 70)
p40 = np.percentile(df_m_a['MEDIA_PONDERATA'], 60)
p50 = np.percentile(df_m_a['MEDIA_PONDERATA'], 50)

print(f"Top 10 %: > {p10}")
print(f"Top 20 %: > {p20}")
print(f"Top 30 %: > {p30}")
print(f"Top 40 %: > {p40}")
print(f"Top 50 %: > {p50}")
# Out:
# Top 10 %: > 30.0
# Top 20 %: > 29.92
# Top 30 %: > 29.77
# Top 40 %: > 29.54
# Top 50 %: > 29.31

# %%
#ISTOGRAMMA MEDIA PONDERATA
N_bins = 15
plt.figure(figsize=(15,8))
plt.title("ISTOGRAMMA NORMALIZZATO MEDIA POND. MAGISTRALE (A)")
plt.xlabel("Media ponderata (in 30 esimi)")
plt.ylabel("Percentuale")
plt.vlines(p10, 0., 1.3, colors='lime', linestyles='solid', label = 'Top 10 %')
plt.vlines(p20, 0., 1.3, colors='red', linestyles='solid', label = 'Top 20 %')
plt.vlines(p30, 0., 1.3, colors='pink', linestyles='solid', label = 'Top 30 %')
plt.vlines(p40, 0., 1.3, colors='yellow', linestyles='solid', label = 'Top 40 %')
plt.vlines(p50, 0., 1.3, colors='brown', linestyles='solid', label = 'Top 50 %')
_, _, _ = plt.hist(df_m_a['MEDIA_PONDERATA'], bins = N_bins, density = True, color = 'navy')
plt.legend(loc = 'upper left')
